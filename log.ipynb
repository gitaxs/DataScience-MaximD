# %%
28.03.2024
Первый урок.

Изучали работу с GitHub, как принимать и отправлять домашнюю работу.
Изучили 3 способа работы с гитом. Первый через сайт, напрямую.
Второй через Кошку Desktop версия гита, чтоб было удобнее работать с пулами.
Третий способ через VSCode.
Пулл реквест или Pull request, это чтото типо общей экосистемы в которой работают разработчики, 
с помощью этого инструмента можно вносить изменения в код и делиться ими с другими участниками совместного
проекта, участники, в свою очередь, могут принять изменения или не принимать их.

На гите (сайт), нажимаю на профиль, захожу в организации, выбираю SENATROVAI, далее выбираю
Probability-Calculators, там можно скопировать код для внесения собственных изменений, чтоб затем
отправить его на проверку.

Так же с помощью гита, я могу дать разрешение на использование и изменение своих проектов,
что упрощает работу в группе, а могу наоборот, делать проект отдельно от других, закрытым.

Пока что не особо со всем разобрался.
