# %%
Второй урок.

Ознакомились с Kaggle, платформой для размещения своего кода, 
на сколько я понял, там можно найти себе работодателя,
если у тебя достаточно развит аккаунт, имеются медальки, посты,
вообщем активно его ведешь.

Снова разбирался с Гитом, вроде бы стало яснее куда и что нажимать,
английский по прежнему вышел из чата.
